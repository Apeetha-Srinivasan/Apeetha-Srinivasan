# %%
#create a list of marks and one more mark
marks_list=[40,37.5,29,32,41]
print(f"This is the initial marks list: {marks_list}")
marks_list.append(44.5)
print(f"This is the marks list after appending: {marks_list}")
# Out:
# This is the initial marks list: [40, 37.5, 29, 32, 41]
# This is the marks list after appending: [40, 37.5, 29, 32, 41, 44.5]

# %%
#Create a tuple of subjects and print the first subject
subjects=("English","Tamil","Mathematics","Science","Social Studies")
print(f"The first subject is : {subjects[0]}")
# Out:
# The first subject is : English

# %%
#Create a set of hobbies (with duplicates) and print it
hobbies={"Dancing","Swimming","Drawing","Painting","Dancing"}
print(f"Printing set with Dupplicate values: {hobbies}")
# Out:
# Printing set with Dupplicate values: {'Drawing', 'Swimming', 'Dancing', 'Painting'}

# %%
#Create a dictionary for a student and add age

Student_base={"Name":"Ganesh","Class":12,"Section":"B"}
Student_base["Age"]=15
print(f"Student details: {Student_base}")
# Out:
# Student details: {'Name': 'Ganesh', 'Class': 12, 'Section': 'B', 'Age': 15}
