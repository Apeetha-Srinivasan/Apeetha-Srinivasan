# %%
import numpy as np

# %%
arr=np.array(1,'int')
arr
# Out:
# array(1)

# %%
arr1=np.array([1,2,3,4])
arr1
# Out:
# array([1, 2, 3, 4])

# %%
arr2=np.array(["apple","mango","banana","orange"])
arr2
# Out:
# array(['apple', 'mango', 'banana', 'orange'], dtype='<U6')

# %%
arr3=np.array([1,2,"hello"])
arr3
# Out:
# array(['1', '2', 'hello'], dtype='<U21')

# %%
#2d array Rows and columns

arr4=np.array([[1,2],[3,4]])
arr4
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
#3d array
arr5 = np.array([
    
        [[5,6],[7,8]],
        [[1,2],[4,6]]
    
])
print(arr5)
print(arr5.shape)
# Out:
# [[[5 6]
#   [7 8]]
#
#  [[1 2]
#   [4 6]]]
# (2, 2, 2)

# %%
#special creation function for array

np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,2))
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
np.full((2,2),7)
# Out:
# array([[7, 7],
#        [7, 7]])

# %%
#identity matrix

identity_matrix=np.eye(1)
print(identity_matrix.shape)
print(identity_matrix)
# Out:
# (1, 1)
# [[1.]]

# %%
ar=np.array([[1,2,3],[5,6,7],[9,10,11]])
ar[0:2,1:3]
# Out:
# array([[2, 3],
#        [6, 7]])

# %%
ar[:,1:]
# Out:
# array([[ 2,  3],
#        [ 6,  7],
#        [10, 11]])

# %%
ar[:,:-1]
# Out:
# array([[ 1,  2],
#        [ 5,  6],
#        [ 9, 10]])

# %%
ar[1][1]=200
ar
# Out:
# array([[  1,   2,   3],
#        [  5, 200,   7],
#        [  9,  10,  11]])

# %%
a=np.array([1,2,3,4])
b=np.array([4,5,6,4])

print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# [5 7 9 8]
# [-3 -3 -3  0]
# [ 4 10 18 16]
# [0.25 0.4  0.5  1.  ]

# %%
np.sum(a)
print(np.sum(a))
# Out:
# 10

# %%
np.sum(b)
print(np.sum(b))
# Out:
# 19

# %%
np.mean(a)
# Out:
# np.float64(2.5)

# %%
np.median(a)
# Out:
# np.float64(2.5)

# %%
np.std(a)
# Out:
# np.float64(1.118033988749895)

# %%
np.min(a)
# Out:
# np.int64(1)

# %%
np.max(a)
# Out:
# np.int64(4)

# %%
np.sqrt(a)
# Out:
# array([1.        , 1.41421356, 1.73205081, 2.        ])

# %%
np.log(a)
# Out:
# array([0.        , 0.69314718, 1.09861229, 1.38629436])

# %%
#reshaping

ar1=np.array([1,2,3,4,5,6])

# %%
ar1.reshape(2,3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a1=np.array([1,2])
a2=np.array([3,4])
np.concatenate((a1,a2))
# Out:
# array([1, 2, 3, 4])

# %%
#treasure hunt game
arr=np.zeros((3,3),dtype=int)
r=np.random.randint(0,3)
c=np.random.randint(0,3)
arr[r,c]=9
row=int(input("enter row: "))
column=int(input("enter column: "))
if arr[row,column]==9:
    print("you won")
else:
    print("try again")
print(arr)
# Out:
# try again
# [[0 0 0]
#  [0 0 0]
#  [0 0 9]]
